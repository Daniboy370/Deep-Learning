# %% [markdown]
# ##Hello !
# Welcome to the **ARpalus** mini-challengce, where your uploaded file will be inferenced by my trained model :
#
# **1)** NAME your file as **"*IMG_inference.jpg*"**. Note that its extension is only -- **"*.jpg*"**
#
# **2)** Upload your file to the folder : **"*/inference*"**
#
# **3)** Go to : **Menu >> Runtime >> Run all**
#
# **4)** Hopefully, it will even work  ~**:^)**

# %%
import cv2
import numpy as np
import glob
import random
import os

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
PATH_dir = '/content/gdrive/My Drive/Colab Notebooks/ARpalus-Challenge/'
os.chdir( PATH_dir )

# if 'darknet' not in os.listdir(PATH_dir):
#     !git clone https://github.com/AlexeyAB/darknet

# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %% [markdown]
# ##Inference w.r.t user data##

# %%
# PATH_darknet = 'content/gdrive/My Drive/Colab Notebooks/ARpalus-Challenge/darknet/'
# PATH_test = PATH_dir + 'inference/IMG_inference.jpg'

os.chdir(PATH_dir)
# %run utils.py
from google.colab.patches import cv2_imshow # fit to colab format

# %%
frame = cv2.imread(PATH_dir+'/inference/IMG_inference.jpg')
bounding_box_frame = run( frame )
cv2_imshow( bounding_box_frame )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ---
# #**Danke !**#
